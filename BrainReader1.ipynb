# %%
from utils import *
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
data = load_table_file("../data/data014.hf5")

# %%
llh = data["llh"]; clip = data["clip"]; guesses = data["guesses"]

# %%
llh.shape
# Out:
# (1, 101)

# %%
plt.plot(llh.squeeze())

# %%
llh = llh.squeeze()[:100]

# %%
weights = rescale(llh[0]/llh)

# %%
plt.plot(weights)

# %%
guesses_weighted_mean = np.average(guesses, 0, weights)

# %%
plt.imshow(rescale(guesses_weighted_mean[13]))

# %%
import scipy.io as sio
index = sio.loadmat("movieindex.mat")

# %%
index["mmv"]
# Out:
# array([[25],
#        [25],
#        [25],
#        ...,
#        [14],
#        [14],
#        [ 2]], dtype=int32)
